# %%
# %matplotlib inline

from __future__ import division

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation

from ipywidgets import interact, HTML, FloatSlider
from IPython.display import clear_output, display
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # Parameter tuning, parameter tuning, parameter tuning...

# %% [markdown]
# <img src="images/sustainedOscillationsDamping2eminus2.png">

# %% [markdown]
# # 2D Equilibrium

# %%
# Load data
ParticlePositionHistory = np.load('2d_equilibrium_position2.npy')
ParticleRhoHistory = np.load('2d_equilibrium_density2.npy')

print ParticlePositionHistory.shape
# Out:
# (400L, 500L, 2L)

# %%
t = 0
stepN = 500

slider = FloatSlider(description='Time', min=1, max=stepN, step=1)

def update_plot():
    time=slider.value
    x = ParticlePositionHistory[time-1,:,0]
    y = ParticlePositionHistory[time-1,:,1]
    fig = plt.figure(figsize=(10,10))
    plt.scatter(x, y, c=ParticleRhoHistory[time-1,:,:])
    plt.xlim(-5e10, 5e10)
    plt.ylim(-5e10, 5e10)
#    plt.colorbar()

    clear_output(True)

slider.on_trait_change(update_plot, 'value')


display(slider)
update_plot()
# Out:
# c:\users\oromi_000\anaconda\lib\site-packages\ipykernel\__main__.py:8: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\users\oromi_000\anaconda\lib\site-packages\ipywidgets\widgets\widget.pyc in _handle_msg(self, msg)
#     392                 for i,k in enumerate(data.get('buffer_keys', [])):
#     393                     sync_data[k] = msg['buffers'][i]
# --> 394                 self.set_state(sync_data) # handles all methods
#     395
#     396         # Handle a state request.
#
# c:\users\oromi_000\anaconda\lib\site-packages\ipywidgets\widgets\widget.pyc in set_state(self, sync_data)
#     283                         self.set_trait(name, from_json(sync_data[name], self))
#     284                     else:
# ...

# %% [markdown]
# # 3D Equilibrium

# %%
ParticlePositionHistory = np.load('3d_equilibrium_position.npy')
ParticleRhoHistory = np.load('3d_equilibrium_density.npy')

stepN = 700

# %%
slider = FloatSlider(description='Time', min=1, max=700, step=1)
ParticlePositionHistory1=np.load('3d_equilibrium_position.npy')

def update_plot():
    time1=int(slider.value)
    x1 = ParticlePositionHistory1[time1-1,:,0]
    y1 = ParticlePositionHistory1[time1-1,:,1]
    z1 = ParticlePositionHistory1[time1-1,:,2]
    figf = plt.figure(figsize=(10,10))
    axf = figf.add_subplot(111, projection='3d')
    axf.scatter(x1, y1, z1)
#     fig = plt.figure(figsize=(10,10))
#     plt.scatter(x, y)
    plt.xlim(-2e10,2e10)
    plt.ylim(-2e10,2e10)
    axf.set_zlim(-2e10,2e10)
    axf.azim=30

    clear_output(True)

slider.on_trait_change(update_plot, 'value')


display(slider)
update_plot()

# %% [markdown]
# # 2D Collision

# %%
ParticlePositionHistory = np.load('2d_collision_position.npy')
ParticleRhoHistory = np.load('2d_collision_density.npy')

# %% [markdown]
# # 3D Collision

# %%
ParticlePositionHistory = np.load('3d_collision_offaxis_position.npy')
ParticleRhoHistory = np.load('3d_collision_offaxis_density.npy')

# %%
slider = FloatSlider(description='Time', min=1, max=2000, step=1)

def update_plot():
    time1=int(slider.value)
    x1 = ParticlePositionHistory[time1-1,:,0]
    y1 = ParticlePositionHistory[time1-1,:,1]
    z1 = ParticlePositionHistory[time1-1,:,2]
    figf = plt.figure(figsize=(10,10))
    axf = figf.add_subplot(111, projection='3d')
    axf.scatter(x1, y1, z1, c=ParticleRhoHistory[time1-1,:,:])
#     fig = plt.figure(figsize=(10,10))
#     plt.scatter(x, y)
    plt.xlim(-2e10,2e10)
    plt.ylim(-2e10,2e10)
    axf.set_zlim(-2e10,2e10)
    axf.azim=90

    clear_output(True)

slider.on_trait_change(update_plot, 'value')


display(slider)
update_plot()
